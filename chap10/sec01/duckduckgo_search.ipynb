# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4o-mini")
model.invoke("최근 제니가 발표한 신곡은 무엇인가요?")
# Out:
# AIMessage(content='제니의 최근 신곡에 대한 정보는 제가 제공할 수 있는 데이터의 한계로 인해 실시간 업데이트가 불가능합니다. 제니 또는 블랙핑크의 공식 소셜 미디어 계정이나 음악 스트리밍 플랫폼을 통해 최신 소식을 확인하시는 것을 추천드립니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 62, 'prompt_tokens': 20, 'total_tokens': 82, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_50906f2aac', 'id': 'chatcmpl-CisQGR06pWZc59ji1AfI9kf9Z6VWy', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--943658fe-db9a-4410-bb9c-ea3c1f99ce15-0', usage_metadata={'input_tokens': 20, 'output_tokens': 62, 'total_tokens': 82, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# %pip install -U duckduckgo-search langchain_community  ddgs
# Out:
# Requirement already satisfied: duckduckgo-search in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (8.1.1)
# Requirement already satisfied: langchain_community in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (0.4.1)
# Requirement already satisfied: ddgs in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (9.9.2)
# Requirement already satisfied: click>=8.1.8 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from duckduckgo-search) (8.3.0)
# Requirement already satisfied: primp>=0.15.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from duckduckgo-search) (0.15.0)
# Requirement already satisfied: lxml>=5.3.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from duckduckgo-search) (6.0.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain_community) (1.1.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain_community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain_community) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain_community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain_community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain_community) (0.4.46)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (1.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (23.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.11.0)
# Requirement already satisfied: certifi in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)
# Requirement already satisfied: fake-useragent>=2.2.0 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from ddgs) (2.2.0)
# Requirement already satisfied: brotli in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.2.0)
# Requirement already satisfied: h2<5,>=3 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.3.0)
# Requirement already satisfied: socksio==1.* in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.1.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/solbi/Documents/GitHub/study-gpt_agent/venv/lib/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.tools import DuckDuckGoSearchResults 

search = DuckDuckGoSearchResults(results_separator=';\n')
docs = search.invoke("최근 제니가 발표한 신곡은 무엇인가요?")

print(docs)
# Out:
# snippet: January 25, 2025 - [서울=뉴시스] 신효령 기자 = 그룹 '블랙핑크' 멤버 겸 솔로가수 제니가 신곡을 기습 공개했다.지난 25일 유튜브 채널 '제니(JENNIE)'에는 ' 제니-젠(JENNIE - ZEN) '이라는 제목의 뮤직비디오 영상이 ..., title: 블랙핑크 제니, 신곡 '젠' 기습 공개…강렬 카리스마 :: 공감언론 뉴시스 ::, link: https://www.newsis.com/view/NISX20250126_0003046568;
# snippet: March 7, 2025 - 제니가 신보 타이틀 ‘ 라이크 제니 ’ 뮤직비디오를 공개했다. 제니는 7일 오후 2시 공식 채널을 통해 첫 번째 솔로 정규 앨범 ‘루비’(Ruby) 타이틀 곡 ‘ 라이크 제니 ’(like JENNIE) ..., title: 제니, 신곡 ‘라이크 제니’ MV 공개…힙한 스타일링에 칼군무, link: https://www.donga.com/news/Entertainment/article/all/20250307/131163699/1;
# snippet: March 19, 2025 - 블랙핑크 제니가 최근 발표한 첫 솔로 앨범 ‘루비’로 빌보드 메인 싱글 차트 ‘핫 100’에 3곡을 동시 진입시키는 기록을 세웠다. 케이(K)팝 여자 솔로 가수 가운데 최초다. 이로써 제니는 통산 6곡의 노래를 ‘핫 100’에 올려, ..., title: 제니, 빌보드 새 역사…첫 솔로 앨범 ‘핫 100’ 3곡 동시 진입, link: https://www.hani.co.kr/arti/culture/music/1187683.html;
# snippet: January 26, 2025 - 그룹 블랙핑크의 제니가 3월 정규 앨범 '루비'의 발매를 앞두고 신곡을 기습 공개했습니다.어제(25일) 제니의 유튜브 채널에는 JENNIE - ZEN 이라는 제목의 뮤직비디오가 올, title: 블랙핑크 제니 신곡 '젠' 기습 공개…역대급 카리스마, link: https://www.yonhapnewstv.co.kr/news/AKR20250126093434057

# %%
# 질의 확장 구현하기
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

question_answering_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "사용자의 질문에 대해 아래 context에 기반하여 답변하라.:\n\n{context}",
        ),
        MessagesPlaceholder(variable_name="messages"),
    ]
)

document_chain = question_answering_prompt | model

# %%
from langchain_classic.memory import ChatMessageHistory

# 채팅 메시지를 저장할 메모리 객체 생성
chat_history = ChatMessageHistory()
# 사용자 질문을 메모리에 저장
chat_history.add_user_message("2025년 현대자동차 미국 시장 전망은 어떻게 되나요?")

# 문서 검색하고 답변 생성
answer = document_chain.invoke(
    {
        "messages": chat_history.messages,
        "context": docs,
    }
)

# 생성된 답변을 메모리에 저장
chat_history.add_ai_message(answer)

print(answer)
# Out:
# content='제가 가지고 있는 데이터는 2023년까지의 정보로, 2025년 현대자동차의 미국 시장 전망에 대한 구체적인 예측을 제공하기는 어렵습니다. 그러나 현대자동차는 전기차 및 친환경 차량 분야에 적극 투자하고 있으며, 미국 시장에서도 이러한 트렌드를 반영할 가능성이 높습니다. 또한, 경쟁사들과의 비교, 소비자 선호도 변화 및 글로벌 경제 상황 등이 2025년 전망에 영향을 미칠 수 있습니다. 관련 전문가의 분석이나 최신 뉴스를 참고하면 보다 구체적인 정보를 얻을 수 있을 것입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 125, 'prompt_tokens': 600, 'total_tokens': 725, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_50906f2aac', 'id': 'chatcmpl-CisTncmKwwdW9xUfEjRaNi4XxDSxf', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--bae2898e-0dce-4b2d-bd36-1a1fb1c5c579-0' usage_metadata={'input_tokens': 600, 'output_tokens': 125, 'total_tokens': 725, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# DuckDuckGo API wrapper를 사용하여 검색할 때 검색 매개변수를 설정하기 위한 클래스 import
from langchain_community.utilities import DuckDuckGoSearchAPIWrapper

# 한국 지역("kr-kr")을 기준, 최근 일주일("w") 내의 검색 결과를 가져오도록 초기화
wrapper = DuckDuckGoSearchAPIWrapper(region="kr-kr", time="w")

# %%
# 검색 기능을 위한 DuckDuckGoSearchResults 초기화
search = DuckDuckGoSearchResults(
    api_wrapper=wrapper,      # 앞에서 정의한 API wrapper를 사용
    source="news",            # 뉴스 소스에서만 검색하도록 지정
    results_separator=';\n'   # 결과 항목 사이에 구분자 사용 (세미콜론과 줄바꿈)
)

# %%
# 검색한 뒤 검색 결과를 docs에 저장
docs = search.invoke("2025년 현대자동차 미국 시장 전망은 어떻게 되나요?")

# 검색 결과 출력
print(docs)
# Out:
# snippet: © 2025 Google LLC., title: 중국반응| 혼다 짝퉁 취급받던 현대자동차 , 미국 시장 진출... - YouTube, link: https://www.youtube.com/watch?v=p_uFCe1m-o8;
# snippet: 수익환원법과 함께 살펴보는 2024 미국 상업용 부동산 폭락 사태. 부동산 시장 전망. Posted in., title: 10년 후 한국의 아파트 부동산 시장 전망은 어떻게 될까? - RocketFolio, link: https://rocketfolio.net/the-outlook-for-south-korean-apartment-real-estate-in-10-years/;
# snippet: 이번 미국 연방정부 셧다운은 과거와 어떻게 다른가? End of TOP 뉴스. 2025 년 11월 9일. 빌딩숲 새 둥지를 실시간 중계하는 '네스트플릭스'에 호주인들이 열광하는 이유., title: 테레사 메이: '치마 속 촬영' 범죄화 법안 곧 통과될 것 - BBC News 코리아, link: https://www.bbc.com/korean/international-44505780;
# snippet: 4. 넥스트에라의 투자 방식이 어떻게 되나요 ? 넥스트에라는 투자자에게 연간 배당금을 제공하여 투자 수익을 실현시킵니다.이종우의 넥스트 스텝 2023-2025 – Kết quả Tìm kiếm Sách của Google., title: 넥스트라 주가: 놀라운 변화에 사로잡히다! Ctr 높은 정보 당선자들이..., link: https://triseolom.net/negseuteura-juga/

# %%
# DuckDuckGo를 이용해 ytn.co.kr 사이트에서 현대자동차 미국 시장 전망에 대한 내용을 검색
docs = search.invoke("site:ytn.co.kr 2025년 현대자동차 미국 시장 전망은 어떻게 되나요?")
docs
# Out:
# 'snippet: 이처럼 트럼프 2기 행정부 시대와 함께, 2025 년 미국 경제에도 큰 변화의 바람이 불어닥칠 것으로 보입니다. 지금까지 뉴욕에서 YTN 이승윤입니다. YTN 이승윤 (risungyoon@ytn.co.kr)., title: [국제] 뉴욕 타임스퀘어에 100만 인파...새해 경제 전망은 ? | YTN, link: https://www.ytn.co.kr/_ln/0104_202501011251307373;\nsnippet: 근데 지금 어떻게 됐어요? 파출소 피하려고 그러다가 검찰청 3개 만났잖아요. 국민통합이라면 굳이 이분을 유임시켜야지 국민통합이 되나요 ? 신율: 나머지는 괜찮으세요?, title: [신율의뉴스정면승부] 인터뷰전문보기 | YTN 라디오, link: https://radio.ytn.co.kr/program/?f=2&id=103384&s_mcd=0263&s_hcd=01;\nsnippet: 4 days ago - [쥐띠]사태를 잘못 파악하면 고립될 위험에 처한다. 1948년생, 거주문제로 마음고생이 따른다. 외출을 자제해라. 1960년생, 빠져 나갈 곳을 찾으나 마땅히 갈 곳이 없다. 1..., title: [운세][오늘의 운세] 2025년 11월 27일 띠별 운세 | YTN, link: https://www.ytn.co.kr/_ln/0121_202511270000000001;\nsnippet: 또 일전에도 말씀드렸지만 AI라는 게 지금 미국 시장을 움직이는 원동력인데 한국 관련 기업은 AI 관련 기업이 거의 없다는 점도 안타까움이라고 볼 수가 있을 것 같고요., title: [경제] 대한항공-아시아나 합병하면 내 주식은 어떻게 되나요 ? | YTN, link: https://ytn.co.kr/_ln/0102_202411290733539034'

# %% [markdown]
# ## 웹페이지 내용 가져오기

# %%
# 검색 결과의 링크들을 저장할 빈 리스트 초기화
links = []

# 검색 결과를 세미콜론과 줄바꿈 기준으로 분리하고, 각 결과 항목에서 링크를 추출
for doc in docs.split(";\n"):
    print(doc)  # 각 검색 결과 항목을 출력하여 확인
    link = doc.split("link:")[1].strip()  # 각 항목에서 'link:' 이후의 URL 부분만 추출
    links.append(link)  # 추출한 링크를 리스트에 추가

# 모든 링크를 출력
print(links)
# Out:
# snippet: January 25, 2025 - [서울=뉴시스] 신효령 기자 = 그룹 '블랙핑크' 멤버 겸 솔로가수 제니가 신곡을 기습 공개했다.지난 25일 유튜브 채널 '제니(JENNIE)'에는 ' 제니-젠(JENNIE - ZEN) '이라는 제목의 뮤직비디오 영상이 ..., title: 블랙핑크 제니, 신곡 '젠' 기습 공개…강렬 카리스마 :: 공감언론 뉴시스 ::, link: https://www.newsis.com/view/NISX20250126_0003046568
# snippet: March 7, 2025 - 제니가 신보 타이틀 ‘ 라이크 제니 ’ 뮤직비디오를 공개했다. 제니는 7일 오후 2시 공식 채널을 통해 첫 번째 솔로 정규 앨범 ‘루비’(Ruby) 타이틀 곡 ‘ 라이크 제니 ’(like JENNIE) ..., title: 제니, 신곡 ‘라이크 제니’ MV 공개…힙한 스타일링에 칼군무, link: https://www.donga.com/news/Entertainment/article/all/20250307/131163699/1
# snippet: March 19, 2025 - 블랙핑크 제니가 최근 발표한 첫 솔로 앨범 ‘루비’로 빌보드 메인 싱글 차트 ‘핫 100’에 3곡을 동시 진입시키는 기록을 세웠다. 케이(K)팝 여자 솔로 가수 가운데 최초다. 이로써 제니는 통산 6곡의 노래를 ‘핫 100’에 올려, ..., title: 제니, 빌보드 새 역사…첫 솔로 앨범 ‘핫 100’ 3곡 동시 진입, link: https://www.hani.co.kr/arti/culture/music/1187683.html
# snippet: January 26, 2025 - 그룹 블랙핑크의 제니가 3월 정규 앨범 '루비'의 발매를 앞두고 신곡을 기습 공개했습니다.어제(25일) 제니의 유튜브 채널에는 JENNIE - ZEN 이라는 제목의 뮤직비디오가 올, title: 블랙핑크 제니 신곡 '젠' 기습 공개…역대급 카리스마, link: https://www.yonhapnewstv.co.kr/news/AKR20250126093434057
# ['https://www.newsis.com/view/NISX20250126_0003046568', 'https://www.donga.com/news/Entertainment/article/all/20250307/131163699/1', 'https://www.hani.co.kr/arti/culture/music/1187683.html', 'https://www.yonhapnewstv.co.kr/news/AKR20250126093434057']

# %%
# Langchain의 WebBaseLoader를 사용하여 웹 페이지의 내용을 불러옵니다.
from langchain_community.document_loaders import WebBaseLoader

# WebBaseLoader 객체를 생성. 'links'는 웹 페이지의 URL 목록을 담고 있는 변수
# bs_get_text_kwargs는 BeautifulSoup의 get_text() 메소드에 전달될 추가 인자
loader = WebBaseLoader(
    web_paths=links,  # 웹 페이지의 링크 목록을 지정
    bs_get_text_kwargs={
        "strip": True  # 웹 페이지에서 텍스트를 가져올 때 앞뒤의 공백을 제거
    },
)

# 비동기로 웹 페이지의 내용을 로드하고, 각 문서를 page_contents 리스트에 추가
page_contents = []  # 각 웹 페이지의 내용을 저장할 리스트입니다.
async for doc in loader.alazy_load():
    page_contents.append(doc)  # 불러온 문서를 page_contents 리스트에 추가

# page_contents에 있는 각 웹 페이지의 내용을 출력
for content in page_contents:
    print(content)  # 웹 페이지의 내용을 출력
    print('--------------')  # 페이지 구분을 위해 구분선을 출력
# Out:
# Fetching pages: 100%|##########| 4/4 [00:00<00:00,  6.96it/s]
# page_content='블랙핑크 제니, 신곡 '젠' 기습 공개…강렬 카리스마 :: 공감언론 뉴시스 ::2025.12.04 (목)서울 -4.9℃K-Artprice프라임뉴시스위클리뉴시스실시간정치국제경제금융산업IT·바이오사회수도권지방문화스포츠연예광장포토TV뉴시스제휴 콘텐츠[속보]코스피, 0.43% 내린 4018.91 출발[속보]뉴욕증시, 금리 인하 기대에 상승 마감…다우 0.86%↑연예연예최신방송/TV영화가요드라마예능해외연예스타블랙핑크 제니, 신곡 '젠' 기습 공개…강렬 카리스마등록 2025.01.26 00:21:05작게크게[서울=뉴시스] 그룹 '블랙핑크' 제니가 신곡 '젠(ZEN)'을 깜짝 공개했다. (사진=유튜브 채널 '제니(JENNIE)' 캡처) 2025.01.26.[email protected]*재판매 및 DB 금지[서울=뉴시스] 신효령 기자 = 그룹 '블랙핑크' 멤버 겸 솔로가수 제니가 신곡을 기습 공개했다.지난 25일 유튜브 채널 '제니(JENNIE)'에는 '제니-젠(JENNIE - ZEN)'이라는 제목의 뮤직비디오 영상이 올라왔다.'젠(ZEN)'은 첫 솔로 정규 앨범 '루비(Ruby)'의 선공개곡이다.제니는 강렬한 눈빛과 카리스마 넘치는 표정을 뽐내며 시선을 압도했다.강한 이미지의 '전사'부터 팜므 파탈의 상징인 '클레오파트라'까지 다양한 변신을 통해 당당한 매력을 발산했다.특히 절도 있는 칼군무는 제니의 무한한 음악적 가능성을 느끼게 했다.'젠' 뮤직비디오의 유튜브 조회 수는 26일 오전 0시 기준으로 422만뷰를 넘어섰다. 현재 유튜브 인기 급상승 동영상 4위에 오르며 인기를 입증했다.제니가 오는 3월7일 첫 솔로 정규앨범 '루비'를 발매한다. 지난해 10월 공개된 '만트라'(Mantra)를 비롯해 총 15곡이 담겼다.세계적 뮤지션들과의 협업곡도 포함돼 전세계 팬들의 기대를 모은다. 제니는 미국 래퍼 겸 프로듀서 차일디시 감비노(Childish Gambino·도널드 글로버)를 비롯해 미국 래퍼 도이치(Doechii), 미국 얼터너티브 뮤지션 도미닉 파이크(Dominic Fike), 영국 팝스타 두아 리파(Dua Lipa), 프랑스 전자음악 뮤지션 FKJ, 미국 싱어송라이터 칼리 우치스(Kali Uchis) 등과 협업했다.제니는 '루비' 발매를 기념해 '더 루비 익스피리언스(The Ruby Experience)' 쇼를 개최한다. 첫 솔로 정규앨범 '루비'를 가까이서 만날 수 있는 자리다. 3월 6일 미국 로스앤젤레스(LA) 피콕 극장에서 시작된다. 이어 10일에는 뉴욕 라디오시티 뮤직홀에서 공연한다. 15일 인천 영종도 인스파이어 아레나에서 한국 공연이 펼쳐진다.[서울=뉴시스] 그룹 '블랙핑크' 제니가 신곡 '젠(ZEN)'을 깜짝 공개했다. (사진=유튜브 채널 '제니(JENNIE)' 캡처) 2025.01.26.[email protected]*재판매 및 DB 금지◎공감언론 뉴시스[email protected]Copyright © NEWSIS.COM, 무단 전재 및 재배포 금지많이 본 사진너구리 침입으로 난장판 된 미 주류 판매장미소짓는 장동혁 대표출국장으로 이동하는 홍명보 축구 국가대표팀 감독이재명 대통령, 외신 기자회견주류 판매장에 침입한 너구리, 결국…사랑스러운 리사제이홉의 여유12월의 신부가 되는 신민아여심저격 필릭스우아한 전지현트리플에스 유닛 미소녀즈 썬뉴시스Pic눈꽃세상으로 변한 한라산 1100고지전장연 출근길 지하철 탑승 시위… 열차 지연 등으로 시민 불편장동혁 "이재명 정권 내란몰이 올인은 할 줄 아는 다른 것 없기 때문"'비상계엄 사태 1년' 국회 앞 다시 밝힌 1만 응원봉…계엄 옹호 맞불 집회도그래픽뉴스2번 접는 폰 '갤럭시 Z 트라이폴드' 공개…출고가 359만원이시간핫뉴스규현, 전 매니저 만행…"도벽·무면허·역주행까지"현영 "이혼하려 했다…금융인 남편과 통장 따로"'47세 미혼' 천명훈 눈물…"결혼한 친구들 부러워"발리서 영화처럼…온주완·방민아 극비 결혼식 공개86세 전원주 "결정사 가입…젊은 남자 팔뚝부터 봐"오늘의 헤드라인"대통령실 "北 억류 국민 문제조속한 남북대화 재개로 해결"대통령실은 4일 현재 북한에 억류된 우리 국민 6명에 대해 "이 문제는 국민적 공감대를 바탕으로 조속한 남북대화 재개 노력을 통해 해결해나갈 것"이라고 밝혔다.
#
# 대통령실은 전날 외신 기자회견에서 제기된 질문에 대한 답변 요지를 이날 이같이 밝혔다.
#
# 12·3 계엄 1년을 맞아 전날 청와대 영빈관에서 열린 외신 기자회견에서 한 기자는 이재명 대통정치국힘, 대여 공세…"'현지누나' 의혹 특검해야"국제트럼프 "푸틴, 美대표단과 좋은 회담…종전 원해"경제美, '한국車 관세 15%' 발효…수출 숨통금융코스닥 시총 장중 사상 첫 500조원 돌파산업"매출 30% 빠져"…입점상인들 '탈팡러시' 불똥IT·바이오정보 털렸는데 '보안 우수'?…쿠팡, 인증 박탈되나사회전국 영하 5도 강추위…오후에는 서울 첫 눈문화왕릉과 맞닿은 화성에 '국립고궁박물관 분관' 조성스포츠김민재vs정우영 불발됐지만뮌헨, 베를린 꺾고 포칼 8강행연예규현, 전 매니저 만행 고백"도벽·무면허·역주행까지"많이 본 기사종합정치국제경제금융산업IT·바이오사회수도권지방문화스포츠연예규현, 전 매니저 만행 고백…"도벽·무면허·역주행까지"'86세' 전원주 "결정사 가입…나이 먹어도 좋은 남자 만날 수 있어"에임드바이오, 오늘 코스닥 상장…따따블 가능성은오승환, 메이저리거 연금 공개…"연 1억원, 사망시 아내가 받아"발리에서 영화처럼…온주완·방민아 극비 결혼식 사진 공개선우용여, 딸 최연제 희생에 울컥 "200억 땅 재판비 내줘"그로쓰리서치 "지슨, 쿠팡 사태 속 무선백도어·도청보안 기술력 주목"손흥민, 비행기서 만난 축덕 女배우와 연락 주고받는다美, 관보에 '한국車 15% 관세 11월1일 소급' 공지…4일 발효(종합2보)국힘, 與 '내란재판부' 법사위 강행 처리에 "위헌법률심판 청구할 것"조현 "한미, 美확장억제 공약·주한미군 지속 주둔 재확인"국힘, 추경호 영장 기각 계기로 대여 공세 강화…"'현지 누나' 의혹 특검도"애완 도마뱀 먹이 주려고 수입 바퀴벌레 구매했다간 처벌 받는다경찰, '성추행 의혹' 장경태 의원 고소인 조사…진술 확보與 '지방선거 출마' 최고위원 사퇴기한 종료…최고위원 후보군은?'비상계엄' 12월3일 공휴일 지정 현실화될까?…찬반 엇갈려"트럼프 행정부 AI 이어 로봇산업에 주목"…테슬라 등 주가 급등트럼프, 車 연비 규제 대폭 완화…소형차 美 생산·판매도 허용 지시죽은 줄 알았던 여성 영안실서 깨어나…英 충격 사건"여친 옆에 앉겠다" 승객 난동에…착륙 30분 앞두고 회항美, 관보에 '한국車 15% 관세 11월1일 소급' 공지…4일 발효(종합2보)美, '한국 자동차관세 15% 소급 인하' 관보 게재출산율 낮다고…중국, 콘돔에 세금 부과美 11월 민간고용 예상 밖 3만2000개↓…금리인하 기대↑(종합)트럼프, 車 연비 규제 대폭 완화…소형차 美 생산·판매도 허용 지시美 11월 민간고용 예상 밖 3만2000개↓…금리인하 기대↑(종합)美민간고용 예상 외 감소…뉴욕증시, 하락 출발"난 이미 서울 전셋집도 포기"…월급 5.5년 고스란히 모아야뉴욕증시, 금리 인하 기대에 상승 마감…다우 0.86%↑미 메이시 백화점, 3분기 호조…6.9조원 팔아 161억원 순익인도 11월 서비스업 PMI 59.8·0.9P↑…"수출수주는 둔화"美 11월 민간고용 예상 밖 3만2000개↓…고용 둔화 지속에임드바이오, 오늘 코스닥 상장…따따블 가능성은그로쓰리서치 "지슨, 쿠팡 사태 속 무선백도어·도청보안 기술력 주목"엔켐 "美 AMPC로 올해 145억 수령 전망"엔젤로보틱스, 말레이시아 의료기기 인허가 획득신한금융, 오늘 회장 선출…진옥동 회장 연임 여부 촉각금감원, 오는 19일 '회계법인·감사반 회계현안 설명회' 개최코스피, 0.43% 내린 4018.91 출발센서뷰, '방산혁신기업 100' 4기 선정트럼프, 車 연비 규제 대폭 완화…소형차 美 생산·판매도 허용 지시"위메프에 당했는데, 또"…'쿠팡 탈퇴' 불똥 튄 입점 상인美, 관보에 '한국車 15% 관세 11월1일 소급' 공지…4일 발효(종합2보)"내 월급 빼고 다 오른다" 진짜네…세금·보험료·물가↑"준비 끝났다"…삼성 '엑시노스2600' 성능 영상 공개美, '한국산 車관세 15% 11월1일자 소급 인하' 관보 게재(종합)현대차, 연구개발 총괄 송창현 AVP본부장 사의…후임은?애완 도마뱀 먹이 주려고 수입 바퀴벌레 구매했다간 처벌 받는다3370만명 털렸는데 '보안 우수'?…쿠팡, 사상 첫 정부 보안 인증 박탈되나"휴면·탈퇴 회원도 피해 가능"…확실한 '탈팡' 지침 확산"무거운 돌이 심장 누르는듯"…기온 뚝 '이 질환' 주의보'얼죽아'와 '뜨아', 내 몸에 맞는 커피 따로 있다넷마블, 개인정보 8000건 추가 유출 확인…주민번호도 포함폭음·폭식 잦은 모임에 간은 '비명'…위도 함께 무너진다'비상계엄' 12월3일 공휴일 지정 현실화될까?…찬반 엇갈려과기정통부·방미통위·우주청(12월 4일 목요일)죽은 줄 알았던 여성 영안실서 깨어나…英 충격 사건"여친 옆에 앉겠다" 승객 난동에…착륙 30분 앞두고 회항출산율 낮다고…중국, 콘돔에 세금 부과"앙앙거리는 신음소리 그만"…이웃 BJ 소음에 입주민 '분통'"스팸·피싱전화 쏟아진다"…쿠팡 사태 후 불안한 일상"휴면·탈퇴 회원도 피해 가능"…확실한 '탈팡' 지침 확산출근길 서울 영하 9도 강추위…수도권 눈 예보수능 채점 결과 오늘 발표…'불국어' 표점, 전과목 만점자 등 주목인천, 첫눈 예보…아침까지 강추위 지속안산시, 코트라 도쿄 무역관에 ASV전용 홍보게시대 설치'경기도지사' 김동연 20.2%·추미애 13.2%·한동훈 10.7%서울시, 청년 고민·성장 담은 웹툰 '서울청년레벨업' 공개경기남부(12월4일 목요일)경기북부(12월4일 목요일)인천·김포·부천(12월4일 목요일)한국공학대, ㈜엔시드에 기술 이전 등철원 옹벽 공사장서 60대 남성 3m 아래로 추락해 숨져목포 죽교동 상가서 화재…불길 확대 '진화 중'청주 실종여성 살해범은 54세 김영우…경찰, 신상공개광주·전남, 아침 최저 영하 6도…바람 강해 체감기온 뚝↓전북 무주 영하 9도 등 출근길 강추위…낮 3~6도 '흐림'충북 밤부터 최대 5㎝ 눈 예보…낮 최고 5도김유상 김해시의원 "낙동강레일파크 일원 체류형관광지로 개발해야"거제시, 한-아세안 국가정원 조성사업 재추진…용역비 정부예산 확보서울시, 청년 고민·성장 담은 웹툰 '서울청년레벨업' 공개문화체육관광부(12월4일 목요일)'국악 가상악기' 클라우디오, 공공데이터 활용 창업경진대회 대상왕릉과 맞닿은 화성에 ‘국립고궁박물관 분관’ 조성…2030년 준공 목표시민이 무대의 주인공…서울시극단 시민연극교실 발표회지원규 PTKOREA 대표, '광고대회 유공광고인' 문체부 장관 표창멘델스존부터 쇼스타코비치까지…국립심포니, 2026 시즌 공개李 대통령 '결국 국민이 합니다', 올해의 책 선정"한국 만나면 행운"…포트2 최약체로 꼽힌 한국홍명보 감독, 조추첨 위해 美 도착…"월드컵 본격 시작"(종합)박찬호 이어 최형우까지 이탈…KIA, 공격력 약화 어쩌나홍명보 감독, 조추첨 위해 워싱턴 입성…"월드컵 본격 시작"영하 날씨에 꽃가루까지…제주 김동준 "공이 안보이더라"죽음의 조 피할까…홍명보호, 6일 운명의 북중미 월드컵 조 추첨손흥민, '친정' 토트넘 찾는다…10일 프라하와 UCL 경기서 팬들에 작별 인사탁구 양하은, WTT 피더 파르마 대회서 단식·혼복 우승…2관왕 등극규현, 전 매니저 만행 고백…"도벽·무면허·역주행까지"'86세' 전원주 "결정사 가입…나이 먹어도 좋은 남자 만날 수 있어"오승환, 메이저리거 연금 공개…"연 1억원, 사망시 아내가 받아"발리에서 영화처럼…온주완·방민아 극비 결혼식 사진 공개선우용여, 딸 최연제 희생에 울컥 "200억 땅 재판비 내줘"손흥민, 비행기서 만난 축덕 女배우와 연락 주고받는다현영 "이혼하려 했다…금융인 남편과 통장 따로"김수용 귓불주름, 심근경색 전조증상?…"노화 현상"뉴시스 기획특집계엄 1년금산분리 갈림길신차 드라이브환율 고공행진매물이 없다많이 본 기사1규현, 전 매니저 만행 고백…"도벽·무면허·역주행까지"2'86세' 전원주 "결정사 가입…나이 먹어도 좋은 남자 만날 수 있어"3오승환, 메이저리거 연금 공개…"연 1억원, 사망시 아내가 받아"4발리에서 영화처럼…온주완·방민아 극비 결혼식 사진 공개5선우용여, 딸 최연제 희생에 울컥 "200억 땅 재판비 내줘"6손흥민, 비행기서 만난 축덕 女배우와 연락 주고받는다7현영 "이혼하려 했다…금융인 남편과 통장 따로"1규현, 전 매니저 만행 고백…"도벽·무면허·역주행까지"2'86세' 전원 ...
# --------------
# page_content='제니, 신곡 ‘라이크 제니’ MV 공개…힙한 스타일링에 칼군무｜동아일보본문으로 바로가기검색창 닫기궁금하신[창원문진석추경호BJ김건희대법원장한화이글스캠벨김민지넷마블서동주한국프로야구성심당퍼 재킷이재명도로 포장유튜버내란전담재판부쿠팡박미선동덕여대원지국민의힘김남국도널드 트럼프공화당추성훈파바로티송가인윤석열창원시자본시장법오늘의 운세더불어민주당]키워드를 검색해 보세요.추천 검색어는 많이 본 뉴스 기사의 키워드를 수집하여 선정하였습니다.검색지우기오피니언정치경제국제사회문화연예스포츠헬스동아트렌드뉴스통합검색마이페이지전체메뉴 펼치기오피니언사설오늘과 내일횡설수설동아광장동아시론광화문에서현장에서POLL정치최신기사대통령실국회정당북한외교안보행정자치경제최신기사기업 CEO부동산금융IT자동차국제최신기사아시아미국/북미유럽중국일본사회최신기사교육노동사건사고사람속으로문화최신기사문학건강요리패션여행연예최신기사방송영화대중음악스포츠최신기사야구&MLB축구골프농구헬스동아최신기사오늘도 건강의료·제약계 소식응급실노후, 어디서 살까셀프 건강 진단함께 미래히어로콘텐츠디스페셜트렌드뉴스실시간 뉴스이슈 포인트연재 포인트뉴스레터 신청기자 구독지면보기PDF서비스회원라운지신문구독동아디지털아카이브보이스뉴스동아방송 DBS동아APP서비스English中文(簡体)日本語연예제니, 신곡 ‘라이크 제니’ MV 공개…힙한 스타일링에 칼군무뉴스1입력2025-03-07 16:072025년 3월 7일 16시 07분코멘트개좋아요개코멘트개공유하기공유하기SNS퍼가기카카오톡으로 공유하기페이스북으로 공유하기트위터로 공유하기URL 복사창 닫기즐겨찾기읽기모드뉴스듣기글자크기 설정글자크기 설정가가가가가창 닫기프린트제니제니가 신보 타이틀 ‘라이크 제니’ 뮤직비디오를 공개했다.제니는 7일 오후 2시 공식 채널을 통해 첫 번째 솔로 정규 앨범 ‘루비’(Ruby) 타이틀 곡 ‘라이크 제니’(like JENNIE) 뮤직비디오를 공개했다.뮤직비디오는 시작과 동시에 제니가 빨간색 우주복을 입고 커튼을 젖히며 등장해 눈길을 끌었다. 이어 제니가 공중에 떠다니는 알파벳 ‘J’ 모양의 무언가를 삼키자, 눈동자 색이 변하며 힙한 스타일링으로 변신해 강렬한 칼군무 퍼포먼스를 펼쳐 짜릿한 쾌감을 선사했다.특히, 제니는 특유의 힙한 매력으로 의상과 연출까지 완벽한 메가 크루 퍼포먼스를 펼쳐 시선을 압도했다.영상 말미에는 처음과 같은 빨간색 우주복을 입은 제니의 몸에 불이 붙었고, 불길이 꺼진 후 제니가 카피바라로 변신해 색다른 재미를 안겼다. 카피바라 옆에는 파란색 장미가 놓여 있어 제니의 새로운 탄생을 알렸다.‘라이크 제니’’ 뮤직비디오는 제니가 가짜 이미지와 거짓된 이야기들에 맞서 싸우고, 결국 자신을 찾아가는 과정이 담겨 있다. 카피바라로 변신하는 엔딩은 거짓을 벗어 던지고, 가장 순수한 자기 자신으로 돌아가는 상징적인 장면이다.타이틀곡 ‘라이크 제니’는 제니가 작사, 작곡에 참여해 개성과 독창성을 강조한 곡으로, 나만의 개성과 색을 잃지 않은 채 당당하게 빛나는 모습을 담고 있다. 자신감을 가지고 나만의 길을 걸어가며 그 누구도 내 자리를 대신할 수 없음을 깨닫는 순간을 노래한다.제니의 첫 솔로 정규앨범 ‘루비’는 음악적으로 다양한 재능과 매력을 보여주는 제니의 색을 담은 앨범으로, 여러 장르의 노래와 콘셉트를 통해 솔로 아티스트로서 제니의 음악적 가능성을 보여준다. 타이틀곡 ‘라이크 제니’를 포함해 다채로운 장르의 총 15곡이 수록됐다.(서울=뉴스1)좋아요0개슬퍼요0개화나요0개댓글0댓글을 입력해 주세요등록오늘의 추천영상지금 뜨는 뉴스동덕여대 공학 전환에 ‘칼부림 예고글’…경찰, 작성자 추적 중같이 술 마시던 지인 흉기 살해한 60대…“칼로 찔렀다” 자백창원 모텔 흉기 난동 사건…피의자 20대男 미리 흉기 준비했다트렌드뉴스많이 본댓글 순1트럼프 “베네수엘라 지상 공격 곧 시작… 콜롬비아도 공습 대상”2창원 모텔 살인사건, 피의자가 여중생 만남 제안했을 가능성 수사3李 “트럼프가 농축우라늄 韓 자체생산 제안, 5대5 동업하기로”4아내 없을 때 엉망된 집 공개한 추성훈 ‘한국 최고 유튜버’ 선정5김남국이 ‘현지 누나’에 부탁한다던 자리, 연봉 2억대 회장직6특검 “통치시스템 파괴”…김건희 “다툴 여지” 헛웃음7서동주, 美 변호사 사칭 의혹에…근무 서류·졸업장 공개8송가인, 美 LA 단독 콘서트 개최…한국 정통 트로트 선보인다9“지하철에 쓰러진 여학생 쉽사리 돕지 못했다…성추행 했다 할까 봐” 씁쓸10“‘검은머리 외국인’ 쿠팡 김범석 한국서 돈벌며 책임은 안져”1李 “내란 덮고 가긴 어렵다” 2차특검 힘 실어2국힘 의원 25명 “尹과 단절…불법 계엄 고개숙여 사죄”3조희대, 李면전서 “사법제도 개편, 국민위한 방향으로 이뤄져야”4李, 尹정권 北도발에 “사과 생각도 하지만…종북몰이 걱정”5특검 “통치시스템 파괴”…김건희 “다툴 여지” 헛웃음6김남국이 ‘현지 누나’에 부탁한다던 자리, 연봉 2억대 회장직7김건희 징역 15년 구형…특검 “대한민국 법 위에 있었다”8李 “대한국민, 노벨평화상 자격 충분…12월 3일 국민주권의 날 지정”9李 “트럼프, 우라늄 농축 동업 제안…5대5로 하기로”10김현지 인사개입 의혹 부른 ‘7인회’ 청탁…대상은 연봉 2억 자리당신만 안 본 뉴스이병헌·박찬욱, 팀버레이크♥비엘 부부 만났다…환한 미소김지유 “스무 살부터 홍대 클럽 다녀…첫차 타고 갔다”‘제조업 CEO와 결혼’ 아유미 “황정음 베이비샤워 갔다 남편 만나”홍진영 깜짝 근황…어딘가 달라진 얼굴?선우용여 “분장실서 담배 피는 여자 연예인 많이 봐”온주완♥민아, 발리 ‘극비’ 결혼식 현장 공개…해변 예식장 눈길“손흥민 전화번호도 안다”…강부자, 남다른 친분 깜짝 공개“역주행하더니 무면허라며 ‘바꿔치기’ 요구”…규현, 前 매니저 만행 폭로연재 칼럼구독 많은실시간 구독 많은최신 업데이트사설구독구독[사설]李 12·3 특별성명 “정의로운 통합”… ‘과유불급’은 경계해야11시간 전황형준의 법정모독구독구독한동훈 “지자체장 선거 나간다 생각, 전혀 해본 적 없어” [황형준의 법정모독]2025-10-20딥다이브구독구독‘반도체 자립’ 꿈은 이루어진다? 글로벌 ‘쩐의 전쟁’ [딥다이브]32분 전정미경의 이런영어 저런미국구독구독“이제 그만” 상대국 정상의 말도 자르는 트럼프식 무례 화법[정미경의 이런영어 저런미국]2025-03-05이전이전딥다이브구독구독‘반도체 자립’ 꿈은 이루어진다? 글로벌 ‘쩐의 전쟁’ [딥다이브]32분 전e글e글구독구독“떡볶이가 너무 쫀득해 못 먹겠다” 막무가내 환불 요청한 손님 [e글e글]32분 전알쓸톡구독구독“머리 말릴 때 냉풍 1분”…결 살고, 드라이기 수명 늘리는 법 [알쓸톡]4시간 전오늘의 운세구독구독[오늘의 운세/12월 4일]7시간 전이전이전오늘과 내일구독구독[오늘과 내일/정임수]신용사회 뒤흔드는 ‘금융 계급제’11시간 전전문의 칼럼구독구독[전문의 칼럼]고품질 의료 데이터, 국가 주도 통합해야 韓 ‘새 먹거리’ 된다7시간 전지금, 이 사람구독구독전장 누빈 젊은 마가, 美공화 텃밭 테네시 지켜냈다[지금, 이 사람]7시간 전사설구독구독[사설]李 12·3 특별성명 “정의로운 통합”… ‘과유불급’은 경계해야1시간 전이전이전닫기댓글0뒤로가기오피니언사설오늘과 내일횡설수설동아광장동아시론광화문에서현장에서POLL정치경제국제사회문화연예스포츠헬스동아함께 미래히어로콘텐츠디스페셜트렌드뉴스실시간 뉴스이슈 포인트연재 포인트뉴스레터 신청기자 구독지면보기PDF서비스신문구독동아디지털아카이브보이스뉴스동아방송 DBS동아APP서비스회원라운지동아일보DAMG 동아미디어 그룹신동아책의 향기주간동아스타일매거진Q여성동아골든걸매거진동아edu+동아비즈니스리뷰하버드비즈니스리뷰코리아동아일보주소 서울특별시 종로구 청계천로 1전화번호 02-2020-0114네이버페이스북인스타그램엑스스레드동아닷컴주소 서울특별시 서대문구 충정로 29전화번호 02-360-0400등록번호 서울아00741발행일자 1996.06.18등록일자 2009.01.16발행·편집인 신석호고객센터이용약관개인정보처리방침청소년보호정책(책임자:구민회)사이트맵저작물 사용제휴안내기사의견·제보정정보도신청광고안내RSS© dongA.com All rights reserved. 무단 전재, 재배포 및 AI학습 이용 금지' metadata={'source' ...
# --------------
# page_content='제니, 빌보드 새 역사…첫 솔로 앨범 ‘핫 100’ 3곡 동시 진입본문문화음악·공연·전시제니, 빌보드 새 역사…첫 솔로 앨범 ‘핫 100’ 3곡 동시 진입K팝 여자 솔로 가수 중 최초이정국기자수정2025-03-20 10:48등록2025-03-19 10:21기사를 읽어드립니다Your browser does not support theaudioelement.0:00제니의 첫 솔로 앨범 ‘루비’. 오에이(OA)엔터테인먼트 제공광고블랙핑크 제니가 최근 발표한 첫 솔로 앨범 ‘루비’로 빌보드 메인 싱글 차트 ‘핫 100’에 3곡을 동시 진입시키는 기록을 세웠다. 케이(K)팝 여자 솔로 가수 가운데 최초다. 이로써 제니는 통산 6곡의 노래를 ‘핫 100’에 올려, 케이팝 여자 가수 최다 기록도 경신했다.미국 음악 전문 매체 빌보드가 18일(현지시각) 발표한 최신 차트(3월22일자)를 보면, ‘루비’의 타이틀곡 ‘라이크 제니’는 ‘핫 100’에서 83위, 두아 리파와 함께 부른 수록곡 ‘핸들바스’는 80위에 올랐다. 여기에 선공개 싱글 ‘엑스트라엘’(피처링 도이치)가 99위로 재진입하면서 동시에 3곡이 ‘핫 100’에 들게 됐다. 케이팝 여자 솔로 가수가 ‘핫 100’에 3곡을 동시 진입시킨 것은 이번이 처음이다. 이전까지 ‘핫 100’에 3곡 이상을 동시 진입시킨 케이팝 아티스트는 방탄소년단(BTS), 뉴진스가 있으며, 솔로로는 방탄소년단 정국이 유일했다.이로써 제니는 총 15곡이 수록된 ‘루비’ 가운데 선공개 싱글 ‘만트라’와 ‘러브 행오버’를 포함, 5곡을 ‘핫 100’에 진입시키는 성과를 이뤘다. 위켄드·릴리 로즈 뎁과의 협업곡 ‘원 오브 더 걸스’까지 포함하면 총 6곡을 ‘핫 100’에 올린 셈이 돼, 이전에 팀 동료 리사가 갖고 있던 5곡의 기록도 깼다.광고‘라이크 제니’는 빌보드 ‘글로벌(미국 제외)’ 3위, ‘글로벌 200’ 5위를 차지하는 등 글로벌 차트에서도 두각을 나타냈다. 메인 앨범 차트 ‘빌보드 200’에선 7위, 영국 오피셜 앨범 차트에선 14일 3위로 데뷔했다.제니가 지난 7일 발표한 ‘루비’는 셰익스피어의 희곡 ‘뜻대로 하세요’에서 영감을 받은 앨범으로, 극장 커튼을 여는 커버 사진은 제니 음악 인생의 새로운 장이 시작되는 것을 상징한다.이정국 기자jglee@hani.co.kr이정국기자다른 기사 어떠세요구독한겨레신문 신청하기세상을 바꾸는 목소리에 힘을 더해주세요여러분의 후원이한겨레의 용기가 됩니다한겨레 후원하기이 기사 어떻게 생각하시나요?좋아요0슬퍼요0화나요0감동했어요0응원해요0뉴스룸 PICK유행 넘어 ‘문화’ 된 러닝…먹방 유튜버도 달린다윤석열, 일본 언론에 “내 계엄은 국민 억압한 계엄과 달라”추경호 ‘기각’ 판사 “윤석열과 2분 통화, 내란 공모 가능한가요?”오늘의 스페셜극우의 울분은 ‘배신당한 정의감’박권일의 우리 안의 극우공군 오폭에 중상 이주노동자…미등록 이유로 국가배상 184만원뿐가장 보통의 사건마크롱 대통령은 어떻게 그 와인을 맞혔을까?천호성의 천병까기귀여움이 경기도 관광 구할 수 있을까이상한 나라의 경기도민남친이 자꾸 ‘아무 말 대잔치’를 해요NativeLab#내란 365일구독내란전담재판부 설치법·법 왜곡죄 개정안 법사위 통과...국힘 퇴장다시 모인 응원봉…국회 앞 3만 시민, 강추위에도 승전 콘서트윤석열의 삼류 법정극, 이제 지겹다 [뉴스룸에서]#이재명 정부구독대통령실 “북한에 억류된 국민 6명 파악…남북대화로 해결할 것”미 관보 ‘한국산 자동차 관세 15%’ 게재…11월1일부터 소급 적용이 대통령 “대북전단 사과하고 싶은데, 종북몰이 걱정”#쿠팡 사태구독쿠팡, 입점업체에 18.9% 고금리 대부업…유출 전 ‘내부자 거래’ 의혹도쿠팡, 미 공시엔 “김범석이 한국 사업 결정권자”…책임회피 비판 커진다쿠팡페이 ‘원 아이디’ 정책에 2차 피해 우려…금감원장 “검사 여부 적극 판단”#내란 특검구독특검, 한덕수 ‘헌법재판관 부실 검증 의혹’ 대통령기록관 압수수색내란전담재판부 설치법·법 왜곡죄 개정안 법사위 통과...국힘 퇴장안규백 ‘명령 따랐을 뿐’이란 내란 장성 겨냥 “‘별의 무게’ 느끼며 책임져야”#김건희 특검구독‘15년 구형’ 들은 김건희 헛웃음…민주 “국민 조롱하나”[단독] 전례 없는 ‘김건희용 액자’ 1천만원…별도 제작에 예산 초과특검 “김건희만 대한민국 법 밖에 존재, 국가 통치 시스템 무너뜨려”#중대재해구독철원 공사현장서 68살 노동자 3m 추락사…계단 설치 중 떨어져김민석 총리 “산재사망 증가 엄중…목숨 잃는 노동자 없도록 최선”하청의 하청, 노동과 안전이 조각난들 ‘어쩔 수 없다’ [전국 프리즘]#검찰 개혁구독검찰 법관 기피 신청에 이화영 ‘술파티 위증 의혹’ 재판 정지[단독] “한동훈이 사악하게 2년 끌어”…윤석열, 도이치 발표 후 박성재에 문자김병기 “항소 포기 국조 받아줬더니 국힘 정작 딴짓…피하는 거냐”#트럼프 관세 전쟁구독미 관보 ‘한국산 자동차 관세 15%’ 게재…11월1일부터 소급 적용EU·캐나다까지 높이는 철강 수입장벽…정부, 피해 최소화 외교 총력“한국, 핵잠 비용 엄청나 신중해야…미국 핵심 우려는 정보보안”#가자 전쟁구독스팅·마크 러팔로 “팔레스타인의 만델라를 석방하라”하마스, 2명 남은 이스라엘 인질 주검 반환…미, ‘휴전 2단계 돌입’ 압박불의한 전쟁 2년, ‘이젠 지쳤다’…떠나는 이스라엘 군인들이전다음광고오늘의 주요기사퇴근 길 ‘폭설급 첫눈’ 예고…추위는 토요일쯤 풀려민주 “문진석 인사 청탁 윤리감찰단 조사할 사안 아냐”송언석 “원조 친명도 한 수 접는 현지 누나…인사농단 책임 물어야”특검, 한덕수 ‘헌법재판관 부실 검증 의혹’ 대통령기록관 압수수색[단독]전례 없는 ‘김건희용 액자’ 1천만원…별도 제작에 예산 초과박지원 “양심 살아있는 국힘 25분에게 박수”…계엄 사과 칭찬지난 가을 9~10월은 ‘늦은 여름’이었다…기온·강수량 역대 2위3천만원 ‘황금알’ 삼킬 땐 몰랐을까, ‘볼일’도 경찰이 지켜볼 줄은유행 넘어 ‘문화’ 된 러닝…먹방 유튜버도 달린다특검 “김건희만 대한민국 법 밖에 존재, 통치 시스템 무너뜨려”이전다음광고광고서비스 전체보기회사소개신문구독후원하기광고안내채용고충처리고객센터저작권회원약관개인정보 처리방침지적재산보호정책이메일주소 무단수집거부한겨레 가족펼치기홈주소 : 서울특별시 마포구 효창목길 6전화번호 : 1566-9595등록번호 : 서울,아01705등록·발행일자 : 2011년 7월 19일발행인 : 최우성편집인·청소년보호책임자 : 김영희사업자명 : 한겨레신문(주)대표자명 : 최우성사업자등록번호 : 105-81-50594통신판매업신고번호 : 마포 2004-02043© 한겨레신문사 All Rights Reserved. 무단 전재, 재배포, AI 학습 및 활용 금지' metadata={'source': 'https://www.hani.co.kr/arti/culture/music/1187683.html', 'title': '제니, 빌보드 새 역사…첫 솔로 앨범 ‘핫 100’ 3곡 동시 진입', 'description': '블랙핑크 제니가 최근 발표한 첫 솔로 앨범 ‘루비’로 빌보드 메인 싱글 차트 ‘핫 100’에 3곡을 동시 진입시키는 기록을 세웠다. 케이(K)팝 여자 솔로 가수 가운데 최초다. 이로써 제니는 통산 6곡의 노래를 ‘핫 100’에 올려, 케이팝 여자 가수 최다 기록도 경신', 'language': 'ko'}
# --------------
# page_content='연합뉴스TV본문으로 바로가기2025.12.04(Thu)장애인 서비스제보LIVE정치경제사회스포츠문화·연예지역세계날씨디지털기획물TV프로그램검색전체메뉴Close문화·연예블랙핑크 제니 신곡 '젠' 기습 공개…역대급 카리스마입력 2025-01-26 09:34:35기사 읽어주기 서비스는 크롬기반의 브라우저에서만 사용하실 수 있습니다.공유하기카카오톡페이스북메신저페이스북X네이버블로그네이버밴드복사글자크기가가가가가그룹 블랙핑크의 제니가 3월 정규 앨범 '루비'의 발매를 앞두고 신곡을 기습 공개했습니다.어제(25일) 제니의 유튜브 채널에는  JENNIE - ZEN이라는 제목의 뮤직비디오가 올라왔습니다.뮤직비디오 속 제니는 강렬한 눈빛과 카리스마 넘치는 표정을 뽐내며 보는 이들의 시선을 압도하는데,  옛 고전 속 여신의 이미지부터 절도 있는 군무는 이번 앨범에 담아낼 제니의 다양한 모습을 예고했습니다.제니의 첫 솔로 정규 앨범 루비는 3월 7일 발매되며, 지난해 10월 공개된 만트라와 젠을 비롯해 15곡의 곡이 실립니다.특히 미국 래퍼 겸 프로듀서 차일디시 감비노(Childish Gambino·도널드 글로버)를 비롯해 미국 래퍼 도이치(Doechii), 미국 얼터너티브 뮤지션 도미닉 파이크(Dominic Fike), 영국 팝스타 두아 리파(Dua Lipa), 프랑스 전자음악 뮤지션 FKJ, 미국 싱어송라이터 칼리 우치스(Kali Uchis) 등과 협업해 기대를 모으고 있습니다.제니는 '루비' 발매를 기념해 '더 루비 익스피리언스(The Ruby Experience)' 쇼를 개최합니다.3월 6일 미국 로스앤젤레스(LA) 피콕 극장을 시작으로 10일에는 뉴욕 라디오시티 뮤직홀에서 공연하고, 15일 인천 영종도 인스파이어 아레나에서 한국 공연이 펼쳐집니다.연합뉴스TV 기사문의 및 제보 : 카톡/라인 jebo23서형석(codealpha@yna.co.kr)당신이 담은 순간이 뉴스입니다!jebo23라인 앱에서 'jebo23' 친구 추가jebo23@yna.co.krⓒ연합뉴스TV, 무단 전재-재배포, AI 학습 및 활용 금지좋아요0응원해요0후속 원해요0ADVERTISEMENT회사소개연합뉴스TV 소개CEO인사말연혁주요경영현황조직운영방침위치안내약관 및 정책개인정보처리방침방송편성규약윤리강령시청자 참여시청자위원회시청자평가원시청자VOC고충처리인시청자게시판알립니다공지사항채널안내큐톤안내광고/비즈니스TV광고문화사업콘텐츠사업디지털광고콘텐츠 유통·플랫폼 제휴관련사이트연합뉴스연합인포맥스연합뉴스TV JOB연합뉴스TV  |  대표이사 : 안수훈  |  서울시 종로구 율곡로2길 25  |  대표전화 02-398-7800  |  사업자등록번호 : 101-86-62619Copyright © 연합뉴스TV. All rights reserved. 무단 전재, 재배포 및 이용(AI 학습 포함) 금지유튜브 채널SNS어떤 기사를 찾으시나요?인기검색어검색창 닫기뉴스최신정치경제사회스포츠문화·연예지역세계날씨디지털기획물TV프로그램뉴스·시사다큐·교양라이프건강바로가기제보라이브시청자게시판진행자소개앱소개RSS서비스' metadata={'source': 'https://www.yonhapnewstv.co.kr/news/AKR20250126093434057', 'title': '연합뉴스TV', 'description': "블랙핑크 제니 신곡 '젠' 기습 공개…역대급 카리스마", 'language': 'ko'}
# --------------

# %%
import requests
from bs4 import BeautifulSoup

# 주어진 URL에서 기사 텍스트를 가져오는 함수
def get_article_text(url):
    try:
        # URL에 GET 요청을 보냄
        response = requests.get(url)
        # 요청이 성공하지 못하면 예외를 발생시킴
        response.raise_for_status()
        
        # BeautifulSoup을 사용하여 HTML 내용을 파싱
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # 클래스가 'story-news article'인 <article> 태그를 찾음
        article = soup.find('article', class_='story-news article')
        
        # 기사를 찾았다면 그 텍스트를 반환
        if article:
            return article.get_text(strip=True)
        else:
            try:
                if soup.find('article'):
                    return soup.find('article').get_text(strip=True)
                elif soup.find('div', id="CmAdContent"):
                    return soup.find('div', id="CmAdContent").get_text(strip=True)
            except:
                return "기사 내용을 찾을 수 없습니다."
            
    # 요청이 실패할 경우 예외 처리
    except requests.exceptions.RequestException as e:
        return f"URL을 가져오는 중 오류 발생: {e}"

# %%
# URL 목록의 각 링크를 반복하면서 기사 텍스트를 출력
articles = []    # 가져온 내용을 리스트에 담기 위한 변수 선언
for link in links:
    print(f"URL: {link}\n")
    article_text = get_article_text(link)
    print(f"Content:\n{article_text}")
    print("--------------------------------------------------")
    articles.append(article_text)
# Out:
# URL: https://www.newsis.com/view/NISX20250126_0003046568
#
# Content:
# [서울=뉴시스] 그룹 '블랙핑크' 제니가 신곡 '젠(ZEN)'을 깜짝 공개했다. (사진=유튜브 채널 '제니(JENNIE)' 캡처) 2025.01.26.[email protected]*재판매 및 DB 금지[서울=뉴시스] 신효령 기자 = 그룹 '블랙핑크' 멤버 겸 솔로가수 제니가 신곡을 기습 공개했다.지난 25일 유튜브 채널 '제니(JENNIE)'에는 '제니-젠(JENNIE - ZEN)'이라는 제목의 뮤직비디오 영상이 올라왔다.'젠(ZEN)'은 첫 솔로 정규 앨범 '루비(Ruby)'의 선공개곡이다.제니는 강렬한 눈빛과 카리스마 넘치는 표정을 뽐내며 시선을 압도했다.강한 이미지의 '전사'부터 팜므 파탈의 상징인 '클레오파트라'까지 다양한 변신을 통해 당당한 매력을 발산했다.특히 절도 있는 칼군무는 제니의 무한한 음악적 가능성을 느끼게 했다.'젠' 뮤직비디오의 유튜브 조회 수는 26일 오전 0시 기준으로 422만뷰를 넘어섰다. 현재 유튜브 인기 급상승 동영상 4위에 오르며 인기를 입증했다.제니가 오는 3월7일 첫 솔로 정규앨범 '루비'를 발매한다. 지난해 10월 공개된 '만트라'(Mantra)를 비롯해 총 15곡이 담겼다.세계적 뮤지션들과의 협업곡도 포함돼 전세계 팬들의 기대를 모은다. 제니는 미국 래퍼 겸 프로듀서 차일디시 감비노(Childish Gambino·도널드 글로버)를 비롯해 미국 래퍼 도이치(Doechii), 미국 얼터너티브 뮤지션 도미닉 파이크(Dominic Fike), 영국 팝스타 두아 리파(Dua Lipa), 프랑스 전자음악 뮤지션 FKJ, 미국 싱어송라이터 칼리 우치스(Kali Uchis) 등과 협업했다.제니는 '루비' 발매를 기념해 '더 루비 익스피리언스(The Ruby Experience)' 쇼를 개최한다. 첫 솔로 정규앨범 '루비'를 가까이서 만날 수 있는 자리다. 3월 6일 미국 로스앤젤레스(LA) 피콕 극장에서 시작된다. 이어 10일에는 뉴욕 라디오시티 뮤직홀에서 공연한다. 15일 인천 영종도 인스파이어 아레나에서 한국 공연이 펼쳐진다.[서울=뉴시스] 그룹 '블랙핑크' 제니가 신곡 '젠(ZEN)'을 깜짝 공개했다. (사진=유튜브 채널 '제니(JENNIE)' 캡처) 2025.01.26.[email protected]*재판매 및 DB 금지◎공감언론 뉴시스[email protected]
# --------------------------------------------------
# URL: https://www.donga.com/news/Entertainment/article/all/20250307/131163699/1
#
# Content:
# 공유하기공유하기SNS퍼가기카카오톡으로 공유하기페이스북으로 공유하기트위터로 공유하기URL 복사창 닫기
# --------------------------------------------------
# URL: https://www.hani.co.kr/arti/culture/music/1187683.html
#
# Content:
# 본문문화음악·공연·전시제니, 빌보드 새 역사…첫 솔로 앨범 ‘핫 100’ 3곡 동시 진입K팝 여자 솔로 가수 중 최초이정국기자수정2025-03-20 10:48등록2025-03-19 10:21기사를 읽어드립니다Your browser does not support theaudioelement.0:00제니의 첫 솔로 앨범 ‘루비’. 오에이(OA)엔터테인먼트 제공광고블랙핑크 제니가 최근 발표한 첫 솔로 앨범 ‘루비’로 빌보드 메인 싱글 차트 ‘핫 100’에 3곡을 동시 진입시키는 기록을 세웠다. 케이(K)팝 여자 솔로 가수 가운데 최초다. 이로써 제니는 통산 6곡의 노래를 ‘핫 100’에 올려, 케이팝 여자 가수 최다 기록도 경신했다.미국 음악 전문 매체 빌보드가 18일(현지시각) 발표한 최신 차트(3월22일자)를 보면, ‘루비’의 타이틀곡 ‘라이크 제니’는 ‘핫 100’에서 83위, 두아 리파와 함께 부른 수록곡 ‘핸들바스’는 80위에 올랐다. 여기에 선공개 싱글 ‘엑스트라엘’(피처링 도이치)가 99위로 재진입하면서 동시에 3곡이 ‘핫 100’에 들게 됐다. 케이팝 여자 솔로 가수가 ‘핫 100’에 3곡을 동시 진입시킨 것은 이번이 처음이다. 이전까지 ‘핫 100’에 3곡 이상을 동시 진입시킨 케이팝 아티스트는 방탄소년단(BTS), 뉴진스가 있으며, 솔로로는 방탄소년단 정국이 유일했다.이로써 제니는 총 15곡이 수록된 ‘루비’ 가운데 선공개 싱글 ‘만트라’와 ‘러브 행오버’를 포함, 5곡을 ‘핫 100’에 진입시키는 성과를 이뤘다. 위켄드·릴리 로즈 뎁과의 협업곡 ‘원 오브 더 걸스’까지 포함하면 총 6곡을 ‘핫 100’에 올린 셈이 돼, 이전에 팀 동료 리사가 갖고 있던 5곡의 기록도 깼다.광고‘라이크 제니’는 빌보드 ‘글로벌(미국 제외)’ 3위, ‘글로벌 200’ 5위를 차지하는 등 글로벌 차트에서도 두각을 나타냈다. 메인 앨범 차트 ‘빌보드 200’에선 7위, 영국 오피셜 앨범 차트에선 14일 3위로 데뷔했다.제니가 지난 7일 발표한 ‘루비’는 셰익스피어의 희곡 ‘뜻대로 하세요’에서 영감을 받은 앨범으로, 극장 커튼을 여는 커버 사진은 제니 음악 인생의 새로운 장이 시작되는 것을 상징한다.이정국 기자jglee@hani.co.kr
# --------------------------------------------------
# URL: https://www.yonhapnewstv.co.kr/news/AKR20250126093434057
#
# Content:
# None
# --------------------------------------------------

# %%
from langchain_core.messages import SystemMessage # 메시지 객체를 만들기 위해 필요

clean_articles = [a for a in articles if a is not None and isinstance(a, str)]

# 2. [핵심 수정] articles가 아니라 'clean_articles'를 사용해야 합니다!
context_text = "\n".join(clean_articles)

# 3. [추가 수정] add_message에는 문자열을 바로 넣을 수 없습니다.
# 검색된 뉴스 내용을 대화 기록에 '참고 자료(Context)'로 넣고 싶다면 SystemMessage로 감싸야 합니다.
chat_history.add_message(SystemMessage(content=context_text))

chat_history.add_user_message("2025년 현대자동차 미국 시장 전망은 어떻게 되나요?")

# 문서 검색하고 답변을 생성
# (참고: invoke 할 때 'context'로 docs를 이미 넘기고 있으므로,
# 위에서 chat_history에 내용을 굳이 추가하지 않아도 답변은 생성됩니다)
answer = document_chain.invoke(
    {
        "messages": chat_history.messages,
        "context": docs,
    }
)

# 생성된 답변 메모리에 저장
chat_history.add_ai_message(answer)
print(answer)
# Out:
# content='제가 현재 가지고 있는 데이터로는 2025년 현대자동차의 미국 시장 전망에 대한 구체적인 정보는 없습니다. 그러나 현대자동차는 전기차 및 자율주행 기술 등 미래 모빌리티에 대한 투자를 늘리고 있어, 이러한 트렌드가 미국 시장에서도 긍정적인 영향을 미칠 가능성이 높습니다. 또한, 미국 내 경쟁 상황과 소비자 선호 변화 등 다양한 요소들이 2025년 판매 성과에 영향을 미칠 수 있습니다. 최신 시장 조사를 참고하거나 자동차 관련 뉴스 및 보고서를 확인하는 것이 좋습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 123, 'prompt_tokens': 2260, 'total_tokens': 2383, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_50906f2aac', 'id': 'chatcmpl-CisYx4ebp7vsj0geFmxaEO94a97xv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--7b1b9e08-ff33-42df-ab3d-ccc113b98ef7-0' usage_metadata={'input_tokens': 2260, 'output_tokens': 123, 'total_tokens': 2383, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
